# %%
from IPython.core.display import display, HTML

# %% [markdown]
# # NEWS INTELLIGENCE
# ## Increasing your competitive edge on capital markets with state of the art machine learning algorithms
#
#
# ### A Case Study by Data Science @d-fine

# %% [markdown]
# ## The Problem
# ![](new_stack.png)

# %% [markdown]
# ## Use Case
# **Use ML to prioritize News for Traders**

# %% [markdown]
# ![](kurse_month.png)

# %% [markdown]
# ## News and Stock Price Change
# ![](kurse.png)

# %% [markdown]
# ## Prediction Problem
# ![](problem.png)

# %%
import pickle
with open('results.dict', 'rb') as in_file:
    data = pickle.load(in_file)
return_string="<table>"
for key,value in data.items():
    if value > .135:
        return_string = return_string + "<tr><td bgcolor=""green""><h4>{}</h4><tr>".format(key)
    else:
        return_string = return_string + "<tr><td><h4>{}</h4><tr>".format(key)
display(HTML(return_string))
# Out:
# <table><tr><td><h4>Interactive Brokers Group Reports Brokerage Metrics for March 2013<IBK</h4><tr><tr><td bgcolor=green><h4>UPDATE 3-Lear settles with activist investors, expands board</h4><tr><tr><td bgcolor=green><h4>Lear settles with activist investors, expands board</h4><tr><tr><td><h4>Fitch: Modified Mortgages Still Pose Credit Risks for U.S. Banks</h4><tr><tr><td><h4>Lightyear Network Solutions Announces Year End 2012 Financial Results<LYNS</h4><tr><tr><td><h4>Russia's MTS urges Tele2 to start talks over $4.25 billion offer</h4><tr><tr><td bgcolor=green><h4>Health Canada Approves Sales of Relora(R) in Canada</h4><tr><tr><td><h4>UPDATE 1-U.S. Supreme Court won't hear airline appeal of ad rule</h4><tr><tr><td><h4>Doctor for French Survivor kills self after contestant dies</h4><tr><tr><td><h4>J.C. Penney's home revamp is make or break for CEO Johnson</h4><tr><tr><td><h4>Supreme Court won't hear airline appeal of ad rule</h4><tr><tr><td bgcolor=green><h4>Ra Pharmaceuticals Announce
# ...

# %% [markdown]
# ## Machine Learning Techniques Used
# ![](model.png)

# %% [markdown]
# ## Results (News relevant for Boeing stock)
# ![](boeing_vs_rest.png)

# %% [markdown]
# For further information, please contact capitalmarkets@d-fine.data
